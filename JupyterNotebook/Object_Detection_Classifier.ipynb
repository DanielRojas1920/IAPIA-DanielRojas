# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielRojas1920/IAPIA-DanielRojas/blob/ModelTrain/JupyterNotebook/Object_Detection_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Object Detection Classifier**
# The porpuse of this Jupyter Notebook is train a Model with the COCO Dataset to be able to classify correclty different types of objects

# %%
# !rm -rf sample_data

# %%
print("hola")
# Out:
# hola

# %% [markdown]
# # **Download COCO Dataset**
# The cells bellow downloads the COCO Dataset to the actual Session (the data is temporal, if the session ends, the data will be lost)
#
# **Important**: The download size is around 20Gb

# %%
#Downloading Training data
# !wget http://images.cocodataset.org/zips/train2017.zip
# Out:
# --2025-04-05 05:20:09--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.30.215, 16.15.177.207, 3.5.27.248, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.30.215|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip         1%[                    ] 263.08M  64.0MB/s    eta 3m 41s ^C

# %%
#Downloading Validation data
# !wget http://images.cocodataset.org/zips/val2017.zip
# Out:
# --2025-04-05 05:20:14--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.210.113, 54.231.228.201, 52.217.234.65, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.210.113|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip           5%[>                   ]  43.05M  30.0MB/s               ^C

# %%
#Downloading Annotation data
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2025-04-05 05:20:15--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.210.113, 54.231.228.201, 52.217.234.65, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.210.113|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
#    annotations_trai  56%[==========>         ] 136.01M  97.0MB/s               ^C

# %% [markdown]
# # **Unpacking the Data**
# The cells bellow unpack the COCO Dataset on the following structure:
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Creating the Directories
# !mkdir -p /data/coco/train2017
# !mkdir -p /data/coco/val2017
# !mkdir -p /data/coco/annotations_trainval2017

#Unzipping the Data
# !unzip train2017.zip -d /data/coco/train2017
# !unzip val2017.zip -d /data/coco/val2017
# !unzip val2017.zip -d /data/coco/annotations_trainval2017
# Out:
# unzip:  cannot find or open train2017.zip, train2017.zip.zip or train2017.zip.ZIP.
# unzip:  cannot find or open val2017.zip, val2017.zip.zip or val2017.zip.ZIP.
# unzip:  cannot find or open val2017.zip, val2017.zip.zip or val2017.zip.ZIP.
